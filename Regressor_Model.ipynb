# %% [markdown]
# <a href="https://colab.research.google.com/github/Donyicoder2006/Project_works/blob/main/Regressor_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ridge Regression**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'/content/New Cleaned Dataset.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  year month_name  sales_qty  sales_amount  user_id  \
# 0           0  2018       July          2           852    16515
# 1           1  2018    October          6          1338    92419
# 2           2  2018   February          2           972    53739
# 3           3  2018        May          1           222    63379
# 4           6  2020        May          6          5412    90846
#
#    Resturant_id        Resturant_Name  \
# 0          8056       Jewels Of India
# 1          2095  Avista Cafe Pizzeria
# 2          9554         Yummy Tummies
# 3          3993                 Dimpi
# 4          1246            Baa Bistro
#
#                                              Cuisine       City   Ratings  \
# 0                                             Mishti    Kolkata  3.200000
# 1                                      Cafe, Italian  Bangalore  4.500000
# 2                                            Chinese    Kolkata  3.591817
# ...

# %%
(data.isnull().sum() * 100)/len(data)
# Out:
# Unnamed: 0        0.0
# year              0.0
# month_name        0.0
# sales_qty         0.0
# sales_amount      0.0
# user_id           0.0
# Resturant_id      0.0
# Resturant_Name    0.0
# Cuisine           0.0
# City              0.0
# Ratings           0.0
# name              0.0
# Age               0.0
# Gender            0.0
# Marital Status    0.0
# Occupation        0.0
# Area              0.0
# dtype: float64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'year', 'month_name', 'sales_qty', 'sales_amount',
#        'user_id', 'Resturant_id', 'Resturant_Name', 'Cuisine', 'City',
#        'Ratings', 'name', 'Age', 'Gender', 'Marital Status', 'Occupation',
#        'Area'],
#       dtype='object')

# %%
data = data.drop(['Unnamed: 0', 'sales_qty','Resturant_id', 'Resturant_Name','user_id','Ratings'], errors='ignore')

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'year', 'month_name', 'sales_qty', 'sales_amount',
#        'user_id', 'Resturant_id', 'Resturant_Name', 'Cuisine', 'City',
#        'Ratings', 'name', 'Age', 'Gender', 'Marital Status', 'Occupation',
#        'Area'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
data = data.drop(['Unnamed: 0', 'sales_qty', 'Resturant_id', 'Resturant_Name', 'user_id','Ratings'], errors='ignore')
display(data.columns)
# Out:
# Index(['Unnamed: 0', 'year', 'month_name', 'sales_qty', 'sales_amount',
#        'user_id', 'Resturant_id', 'Resturant_Name', 'Cuisine', 'City',
#        'Ratings', 'name', 'Age', 'Gender', 'Marital Status', 'Occupation',
#        'Area'],
#       dtype='object')

# %%
data = pd.read_csv(r'/content/New Cleaned Dataset.csv')
data = data.drop(['Unnamed: 0', 'sales_qty', 'Resturant_id', 'Resturant_Name', 'user_id'], errors='ignore')
display(data.columns)
# Out:
# Index(['Unnamed: 0', 'year', 'month_name', 'sales_qty', 'sales_amount',
#        'user_id', 'Resturant_id', 'Resturant_Name', 'Cuisine', 'City',
#        'Ratings', 'name', 'Age', 'Gender', 'Marital Status', 'Occupation',
#        'Area'],
#       dtype='object')

# %%
print("Columns before drop:")
print(data.columns.tolist())

data = data.drop(['Unnamed: 0', 'sales_qty', 'Resturant_id', 'Resturant_Name', 'user_id'], errors='ignore')

print("\nColumns after drop:")
print(data.columns.tolist())
# Out:
# Columns before drop:
# ['Unnamed: 0', 'year', 'month_name', 'sales_qty', 'sales_amount', 'user_id', 'Resturant_id', 'Resturant_Name', 'Cuisine', 'City', 'Ratings', 'name', 'Age', 'Gender', 'Marital Status', 'Occupation', 'Area']
#
# Columns after drop:
# ['Unnamed: 0', 'year', 'month_name', 'sales_qty', 'sales_amount', 'user_id', 'Resturant_id', 'Resturant_Name', 'Cuisine', 'City', 'Ratings', 'name', 'Age', 'Gender', 'Marital Status', 'Occupation', 'Area']

# %%
data = data.drop(['Ratings'], axis=1)
print(data.columns.tolist())
# Out:
# ['year', 'month_name', 'sales_amount', 'Cuisine', 'City', 'name', 'Age', 'Gender', 'Marital Status', 'Occupation', 'Area']

# %%
data.columns
# Out:
# Index(['year', 'month_name', 'sales_amount', 'Cuisine', 'City', 'name', 'Age',
#        'Gender', 'Marital Status', 'Occupation', 'Area'],
#       dtype='object')

# %%
x = data.drop('sales_amount', axis=1)
y = data['sales_amount']

# %%
x.columns
# Out:
# Index(['year', 'month_name', 'Cuisine', 'City', 'name', 'Age', 'Gender',
#        'Marital Status', 'Occupation', 'Area'],
#       dtype='object')

# %%
catcol = x.select_dtypes(include=['object']).columns.tolist()
catcol
# Out:
# ['month_name',
#  'Cuisine',
#  'City',
#  'name',
#  'Gender',
#  'Marital Status',
#  'Occupation',
#  'Area']

# %%
numcol = x.select_dtypes(include=['int64', 'float64']).columns.tolist()
numcol
# Out:
# ['year', 'Age']

# %%
from sklearn.preprocessing import OrdinalEncoder
Encoder = OrdinalEncoder()

# %%
x_encoded = Encoder.fit_transform(x[catcol])

# %%
x_encoded_df = pd.DataFrame(x_encoded, columns=catcol)
display(x_encoded_df.head())
# Out:
#    month_name  Cuisine  City     name  Gender  Marital Status  Occupation  \
# 0         5.0   2093.0  19.0  16010.0     0.0             2.0         3.0
# 1        10.0    746.0   3.0  20237.0     1.0             2.0         3.0
# 2         3.0    993.0  19.0   4344.0     0.0             2.0         3.0
# 3         8.0    163.0  19.0   5142.0     1.0             2.0         0.0
# 4         8.0   2637.0  11.0  24343.0     0.0             2.0         3.0
#
#     Area
# 0   79.0
# 1  259.0
# 2  746.0
# 3  694.0
# 4  433.0

# %%
train_df = pd.concat([x_encoded_df, x[numcol]], axis=1)
display(train_df.head())
# Out:
#    month_name  Cuisine  City     name  Gender  Marital Status  Occupation  \
# 0         5.0   2093.0  19.0  16010.0     0.0             2.0         3.0
# 1        10.0    746.0   3.0  20237.0     1.0             2.0         3.0
# 2         3.0    993.0  19.0   4344.0     0.0             2.0         3.0
# 3         8.0    163.0  19.0   5142.0     1.0             2.0         0.0
# 4         8.0   2637.0  11.0  24343.0     0.0             2.0         3.0
#
#     Area  year  Age
# 0   79.0  2018   23
# 1  259.0  2018   23
# 2  746.0  2018   23
# 3  694.0  2018   26
# 4  433.0  2020   23

# %%
from sklearn.preprocessing import RobustScaler

# Initialize the RobustScaler
scaler = RobustScaler()

# Apply the scaler to the numerical columns in train_df
train_df[numcol] = scaler.fit_transform(train_df[numcol])

# Display the head of the transformed DataFrame
display(train_df.head())
# Out:
#    month_name  Cuisine  City     name  Gender  Marital Status  Occupation  \
# 0         5.0   2093.0  19.0  16010.0     0.0             2.0         3.0
# 1        10.0    746.0   3.0  20237.0     1.0             2.0         3.0
# 2         3.0    993.0  19.0   4344.0     0.0             2.0         3.0
# 3         8.0    163.0  19.0   5142.0     1.0             2.0         0.0
# 4         8.0   2637.0  11.0  24343.0     0.0             2.0         3.0
#
#     Area  year       Age
# 0   79.0   0.0 -0.333333
# 1  259.0   0.0 -0.333333
# 2  746.0   0.0 -0.333333
# 3  694.0   0.0  0.666667
# 4  433.0   2.0 -0.333333

# %%
y_scaled = scaler.fit_transform(y.values.reshape(-1, 1))

# %%
x_train, x_test, y_train, y_test = train_test_split(train_df, y_scaled, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import r2_score

# Ridge Regression
ridge_model = Ridge(alpha=1.0)  # You can tune alpha
ridge_model.fit(x_train, y_train)
# Out:
# Ridge()
